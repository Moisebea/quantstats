# %%
import quantstats as qs

# %%
stock = 'SPY'
portofolio = qs.utils.download_returns(stock,period='2y')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(f"Sharpe:{qs.stats.sharpe(portofolio)}")
# Out:
# Sharpe:0.0646686179919487

# %%
print(f"Best Day:{qs.stats.best(portofolio)}")
print(f"Best Months:{qs.stats.best(portofolio,aggregate='M')}")
# Out:
# Best Day:0.054954153075837064
# Best Months:0.09208744926275636

# %%
qs.extend_pandas()

# %%
print(portofolio.cagr)
print(portofolio.max_drawdown)
print(portofolio.monthly_returns())
# Out:
# <bound method cagr of Date
# 2021-09-28         NaN
# 2021-09-29    0.001683
# 2021-09-30   -0.012222
# 2021-10-01    0.011884
# 2021-10-04   -0.012896
#                 ...
# 2023-09-22   -0.002249
# 2023-09-25    0.004205
# 2023-09-26   -0.014691
# 2023-09-27    0.000399
# 2023-09-28    0.004623
# Name: Close, Length: 504, dtype: float64>
# <bound method max_drawdown of Date
# 2021-09-28         NaN
# 2021-09-29    0.001683
# 2021-09-30   -0.012222
# 2021-10-01    0.011884
# 2021-10-04   -0.012896
#                 ...
# 2023-09-22   -0.002249
# 2023-09-25    0.004205
# 2023-09-26   -0.014691
# 2023-09-27    0.000399
# 2023-09-28    0.004623
# Name: Close, Length: 504, dtype: float64>
#            JAN       FEB       MAR       APR       MAY       JUN       JUL  \
# 2021  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2022 -0.052741 -0.029517  0.034377 -0.087769  0.002257 -0.086407  0.092087
# ...

# %%
index ={"AAPL": 1.3,"AGG":-.3,"NVDA":1.5,"META":-.5}
investment =qs.utils.make_index(index,period='3y')
investment.index=investment.index.tz_localize(None)
investment.plot_earnings(start_balance=100000)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\quantstats\utils.py:400: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return index[index.index <= last_day].sum(axis=1)

# %%
investment.plot_monthly_heatmap()

# %%
investment.plot_rolling_volatility()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
qs.reports.full(investment)
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2020-09-29
# End Period                 2023-09-28
# Risk-Free Rate             0.0%
# Time in Market             99.0%
#
# Cumulative Return          30.56%
# CAGR﹪                     6.34%
#
# Sharpe                     0.63
# Prob. Sharpe Ratio         86.54%
# Smart Sharpe               0.62
# Sortino                    0.93
# Smart Sortino              0.91
# Sortino/√2                 0.66
# Smart Sortino/√2           0.64
# Omega                      1.12
#
# Max Drawdown               -96.25%
# Longest DD Days            640
# Volatility (ann.)          110.42%
# Calmar                     0.07
# Skew                       0.12
# Kurtosis                   2.69
#
# Expected Daily %           0.03%
# Expected Monthly %         0.72%
# Expected Yearly %          6.89%
# Kelly Criterion            5.24%
# Risk of Ruin               0.0%
# ...
